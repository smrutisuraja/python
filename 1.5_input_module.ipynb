# %% [markdown]
# ## module,package,function
#
# package =  collection of modules

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import math
math.sqrt(25) # in this place we import math so we can find the sqrt of 25
# Out:
# 5.0

# %%
round(math.sqrt(49)) ## another way to print withou any problem
# Out:
# 7

# %%
x = round(math.sqrt(49))  ## give a variable to this
x
# Out:
# 7

# %%
math.floor(3.8) ## in 3.8 it is bigger than 3 and smaller than 4 so in math.floor() we get the smaller
# Out:
# 3

# %%
math.ceil(3.8) ## in this we get biger 4
# Out:
# 4

# %%
pow(3,2)  ## we use pow to output the square of any number
# Out:
# 9

# %%
math.pi
# Out:
# 3.141592653589793

# %%
help()

# %% [markdown]
# in python there is no constant only variables

# %%
import math  ## in this we add import function
math.sqrt(25)
# Out:
# 5.0

# %%
import math as m  ## in this case math is big word so in all time it is not use so that we add m as math in this place of math we can simply use m
m.sqrt(49)
# Out:
# 7.0

# %%
# import nareshitechnology as nit 
# import indianintechnolgomumbai as iitm

# %%
from math import sqrt,pow ## math has many function if you want to import specific function then use import(in this i import two function sqrt and pow)
print(pow(2,3))
print(m.sqrt(10))
# Out:
# 8.0
# 3.1622776601683795

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
from math import * ## if i add * in the place of function then it shows all function of math eg - sqrt and pow and etc
print(pow(2,3))
print(m.sqrt(10))

# %% [markdown]
# # input()

# %%
input()
# Out:
# '10'

# %%
input()
input()
# Out:
# '20'

# %%
x = input()
y = input()
z = x + y
print(z)
# Out:
# 1020

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x = int(input("Enter a number"))
x
# Out:
# 10

# %%
x1 = input("Enter 1st number: ")  #whenevery you works in input function it always give you string 
x2 = input("Enter 2nd number: ")  # it wont understand as arithmetic operator
z1 = x1 + x2
print(z1)
# Out:
# 1020

# %%
y1 = int(input("Enter 1st number: "))  #whenevery you works in input function it always give you string 
y2 = int(input("Enter 1st number: "))  # it wont understand as arithmetic operator
z2 = y1 + y2
print(z2)
# Out:
# 30

# %%
x2 = input('Enter user_name: ') #whenevery you works in input function it always give you string 
y2 = input('Enter password: ') # it wont understand as arithmetic operator
z2 = x2 + y2
print(z2)
# Out:
# smrutisurajasitu@134

# %%
st = input("enter a string")
print(st)
print(type(st))
# Out:
# situ
# <class 'str'>

# %%
st = input("enter a string")[0]
print(st)
# Out:
# s

# %%
st = input("enter a string")[0:2]
print(st)
# Out:
# si

# %%
st = input("enter a string")[9:13]
print(st)
# Out:
# 513

# %%
st = input("enter a string")[9:13:2]
print(st)
# Out:
# 53
