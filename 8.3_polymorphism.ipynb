# %% [markdown]
# #  Polymorphism
#
#
# Polymorphism is a core concept in Object-Oriented Programming (OOP) that allows objects of different classes to be treated as objects of a common superclass. It provides a way to perform a single action in different forms. Polymorphism is typically achieved through method overriding and interfaces

# %% [markdown]
# ## Method overridiing
#
# Method overriding allowws a child class too provide a specific implementation of a method that is already defined in its parent class

# %%
## base speak
class Animal:
    def speak(self):
        return "sound of a animal"

# Derived class 1
class Dog(Animal):
    def speak(self):
        return "Woof!"

# Derived class

class Cat(Animal):
    def speak(self):
        return "Meow!"

# Function  that demonstartes polymorphism
def animal_speak(animal):
    print(animal.speak())

dog = Dog()
cat =Cat()
print(dog.speak())
print(cat.speak())
animal_speak(dog)
# Out:
# Woof!
# Meow!
# Woof!

# %%
## polymorphism with functions and methods
## base class

class shape:
    def area(self):
        return "the area of the figure"

# derived class 1
class Rectangle(shape):
    def __init__(self,width,height):
        self.width= width
        self.height = height

    def area(self):
        return self.width * self.height

# derived class 2
class Circle(shape):
    def __init__(self,radius):
        self.radius = radius

    def area(self):
        return 3.14*self.radius*self.radius


## function that demonstrates polymorphism

def print_area(shape):
    print(f"the area is {shape.area()}")

rectangle = Rectangle(4,5)
circle = Circle(3)

print_area(rectangle)
print_area(circle)
# Out:
# the area is 20
# the area is 28.259999999999998

# %% [markdown]
# ## polymorphism eith Abstract base class
#
# Abstract Base Classes (ABCs) are used to define common methods for a group of related objects. They can enforce that derived classes implement particular methods, promoting consistency across different implementations.

# %%
from abc import ABC,abstractmethod

## define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

# deriveed class 1

class Car(Vehicle):
    def start_engine(self):
        return "car engine strated"

## deriveed class 1

class Motorcycle(Vehicle):
    def start_engine(self):
        return "motorcycle engine strated"

## function that demonstrates polymorphism

def start_vehicle(vehicle):
    print(vehicle.start_engine())

# creates objects of a car and motor cycle

car = Car()
motorcycle = Motorcycle()

start_vehicle(car)
start_vehicle(motorcycle)
# Out:
# car engine strated
# motorcycle engine strated
