# %%
## arithmatic operartion

a = 10
b = 15
add_result =  a+b #addition
sub_result =  a-b # substraction
mult_result =  a*b #mltiplication
division_result =  a/b #division
floor_division_result =  a//b ## floor division
modelus_result = a%b # modulus operation
exponential_result = a**b #exponetion
print(add_result)
print(sub_result)
print(mult_result)
print(division_result)
print(floor_division_result)
print(modelus_result)
print(exponential_result)
# Out:
# 25
# -5
# 150
# 0.6666666666666666
# 0
# 10
# 1000000000000000

# %%
21/5
# Out:
# 4.2

# %%
21//5
# Out:
# 4

# %%
# comparision operartor
## ==

a = 10
b = 10

a == b
# Out:
# True

# %%
str1 = "max"
str2 = "max"

str1 == str2
# Out:
# True

# %%
## not equal to (symbol = !=)
str1 != str2
# Out:
# False

# %%
str3 = "Max"
str4 = "max"

str3!=str4
# Out:
# True

# %%
## greater than (>)

num1 = 45
num2 = 65

num1>num2
# Out:
# False

# %%
num1<num2
# Out:
# True

# %%
## greater than or equal to

number1 = 45
number2 = 45

number1>=number2
# Out:
# True

# %%
## greater than or equal to

number1 = 44
number2 = 45

number1>=number2
# Out:
# False

# %%
## greater than or equal to

number1 = 45
number2 = 45

number1<=number2
# Out:
# True

# %%
## logical operators

## and ,not ,or

x =True
y = False

result = x and y
print(result)
# Out:
# False

# %% [markdown]
# ## if x and y one is false then in and operator it give false
# ## it gives true if x and y are true

# %%
x =True
y = True

result = x and y
print(result)
# Out:
# True

# %% [markdown]
# ## OR OPERATION
# ## in or operation if x and y one is true then the output is true
# ## if x and y both are false in this time false is in output

# %%
## or 
x =True
y = False

result = x or y
print(result)
# Out:
# True

# %% [markdown]
# ## NOT OPERATION
# it is the reverse of if x is true then not x is false

# %%
## not operation
x = True
not x
# Out:
# False

# %%
num1 = float(input("enter first number:"))
num2 = float(input("enter first number:"))

addition = num1+num2
substrtion = num1-num2
multiplication = num1*num2
division = num1/num2
floor_division = num1//num2
modulus = num1%num2
exponential = num1**num2

print("addition:" , addition)
print("substrtion:",substrtion)
print("multiplication:",multiplication)
print("division:",division)
print("floor_division:",floor_division)
print("modulus:",modulus)
print("exponential:",exponential)
# Out:
# addition: 30.0
# substrtion: -10.0
# multiplication: 200.0
# division: 0.5
# floor_division: 0.0
# modulus: 10.0
# exponential: 1e+20
