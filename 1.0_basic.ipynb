# %% [markdown]
# syntax =  how we about to arrange a word so that write the code
#
# semantics = enterpretation (what the code is supposed to do when the code is runs)

# %%
## basic syntax rules in python
## case sensitivity : python is a case sensitivity

name = "max"
Name =  "whatson"

print(name)
print(Name)  ##both the variable is are having the case sensitivity things
# Out:
# max
# whatson

# %%
## indentation
## python uses indentation to define block of codes. consistent uses of space (commonlly 4) or a tab is requared.

age = 32
if age > 30:
    print(age)
print(age)
# Out:
# 32
# 32

# %%
## this is a single line comment
print("hello world")
# Out:
# hello world

# %%
## line continuation

total = 1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
t  = 1+2+3+4+5+6+\
8+9+10
print(t)
# Out:
# 48

# %%
## multiple statement in single line
x = 5;y = 10;z = x+y
print(z)
# Out:
# 15

# %%
## understand the semantics in python
## variable assignment
age = 32 ##age is an integer
name = "max" ## max is an string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## type inference
variable = 10
print(type(variable))
variable = "max"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 32
if age > 30:
    print(age)
# Out:
# 32

# %%
## name eror
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 ## name eror
# ----> 2 a = b
#
# NameError: name 'b' is not defined

# %%
## code examples of indentation

if True:
    print("correct indentaton")
    if False:
        print("this dont print")
    print("this will print" )
print("outside the if block")
# Out:
# correct indentaton
# this will print
# outside the if block
