# %% [markdown]
# # Understanding Exception
#
# Exception handling in python aloows you to handle error gracefully and take corrective action without stopping the execution of the program. This lession will cover the basic of exception, including how to use try,except else and final blocks.

# %% [markdown]
# # What Are Exceptions?
#
# Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#
# ZeroDivisionError: Dividing by zero.
#
# FileNotFoundError: File not found.
#
# ValueError: Invalid value.
#
# TypeError: Invalid type.

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %%
# Exception try, except block

try:
    a = b
except:
    print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
try:
    a = b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 1/0
except ZeroDivisionError  as ex:
    print(ex)
    print("please enter the dominator greater than 0")
# Out:
# division by zero
# please enter the dominator greater than 0

# %%
try:
    result = 1/2
    a = b
except ZeroDivisionError  as ex:
    print(ex)
    print("please enter the dominator greater than 0")
except Exception as ex1:
    print(ex1)
    print("Main exception got caught here")
# Out:
# name 'b' is not defined
# Main exception got caught here

# %%
try:
    num = int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")

except ZeroDivisionError:
     print("enter dominator greater than 0")
except Excetion as ex:
    print(ex)
# Out:
# enter dominator greater than 0

# %%
# try,except,else block
try:
    num = int(input("Enter a number:"))
    result = 10/num
except ValueError:
    print("This is not a valid number")

except ZeroDivisionError:
     print("you can't divide by 0")
except Excetion as ex:
    print(ex)
else:
    print(f"the result is{result}")
# Out:
# the result is0.43478260869565216

# %%
## try,except,else and finally

try:
    num = int(input("Enter a number:"))
    result = 10/num
except ValueError:
    print("This is not a valid number")

except ZeroDivisionError:
     print("you can't divide by 0")
except Excetion as ex:
    print(ex)
else:
    print(f"the result is{result}")
finally:
    print("Execution complete.")
# Out:
# the result is0.8333333333333334
# Execution complete.

# %%
## file handling and exception handling

try:
    file = open('example1.txt','r')
    content = file.read()
    print(content)

except FileNotFoundError:
    print("the file does not exists")
except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print('file close')
# Out:
# file close

# %%
try:
    file = open('example1.txt','r')
    content = file.read()
    a = b
    print(content)

except FileNotFoundError:
    print("the file does not exists")
except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print('file close')
# Out:
# name 'b' is not defined
# file close
