# %%
int(2.3)
# Out:
# 2

# %%
int(2.3 ,3.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int(2.3 ,3.4)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(2.3)
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int("ten")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int("ten")
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # int can type casting with float ,bool and string(if there is a number) only

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(20.0)
# Out:
# 20.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# # float can type casting with int , bool ,string(if there is a number)

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool(10)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool('zero')
# Out:
# True

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10, 20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3,4.5)
# Out:
# (2.3+4.5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True ,False)
# Out:
# (1+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex("situ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 complex("situ")
#
# ValueError: complex() arg is a malformed string

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
str(100)
# Out:
# '100'

# %%
str(10.23)
# Out:
# '10.23'

# %%
str(10+2j)
# Out:
# '(10+2j)'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 str(2,3)
#
# TypeError: str() argument 'encoding' must be str, not int

# %% [markdown]
# ## operators

# %% [markdown]
# # Arithmatic operators [ + , - , * , / , // , % , ** ]

# %%
num1 = float(input("enter 1st number"))
num2 = float(input("enter 2nd number"))

# arithmatic operators

print(f"{num1} + {num2} = {num1 + num2}")
print(f"{num1} - {num2} = {num1 - num2}")
print(f"{num1} * {num2} = {num1 * num2}")
print(f"{num1} / {num2} = {num1 / num2}")
print(f"{num1} // {num2} = {num1 // num2}")
print(f"{num1} % {num2} = {num1 % num2}")
print(f"{num1} ** {num2} = {num1 ** num2}")
# Out:
# 10.0 + 20.0 = 30.0
# 10.0 - 20.0 = -10.0
# 10.0 * 20.0 = 200.0
# 10.0 / 20.0 = 0.5
# 10.0 // 20.0 = 0.0
# 10.0 % 20.0 = 10.0
# 10.0 ** 20.0 = 1e+20

# %%
oct(25)
# Out:
# '0o31'

# %%
print(0xa)
# Out:
# 10

# %%
hex(16)
# Out:
# '0x10'

# %%
hex(32)
# Out:
# '0x20'

# %%
0o31
# Out:
# 25

# %%
~5
# Out:
# -6

# %%
12&13
# Out:
# 12

# %%
12|13
# Out:
# 13

# %%
0^0
# Out:
# 0

# %%
12^13
# Out:
# 1

# %%
12^12
# Out:
# 0

# %%
12<<1
# Out:
# 24

# %%
12>>1
# Out:
# 6

# %%
# Out:
# (1+0j)
